# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankaNav/AutoNumberPlate/blob/master/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing and Unzipping Tiny Imagenet dataset

# %%
# !ls
# !rm -rf  training_1
# !ls
# !mkdir training_3
# Out:
# sample_data  tiny-imagenet-200	tiny-imagenet-200.zip  training_2  training_3
# mkdir: cannot create directory ‘training_3’: File exists

# %%
## Download the dataset and unzip it everytime the session crashes.
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Out:
# --2019-04-07 04:52:42--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  20.1MB/s    in 15s
#
# 2019-04-07 04:52:58 (15.9 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]

# %%
## Skip the unzip if unzipped dataset is already present in the directory.
# !ls
# !unzip -qq 'tiny-imagenet-200.zip'
# !ls
# Out:
# sample_data  tiny-imagenet-200.zip  training_2
# sample_data  tiny-imagenet-200	tiny-imagenet-200.zip  training_2

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib  inline
from keras.preprocessing.image import ImageDataGenerator

# %%
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
val_data.head(3)
# Out:
#          File      Class
# 0  val_0.JPEG  n03444034
# 1  val_1.JPEG  n04067472
# 2  val_2.JPEG  n04070727

# %%
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    zoom_range = 0.2,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    fill_mode='nearest'
    )


valid_datagen = ImageDataGenerator(rescale=1./255,rotation_range=8, width_shift_range=0.08, shear_range=0.3,
                         height_shift_range=0.08, zoom_range=0.08)

train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(64, 64), color_mode='rgb', 
                                                    batch_size=512, class_mode='categorical', shuffle=True, interpolation='bicubic')

validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(64, 64),
                                                    color_mode='rgb', class_mode='categorical', batch_size=512, shuffle=True,interpolation='bicubic')
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.

# %%
x_batch, y_val_batch = next(train_generator)
x_batch.shape
# Out:
# (512, 64, 64, 3)

# %%
# Plot Generator images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')

# %% [markdown]
# ##Resnet

# %%
from __future__ import division

import six
from keras.models import Model
from keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten
)
from keras.layers.convolutional import (
    Conv2D,
    MaxPooling2D,
    AveragePooling2D
)

from keras.layers import GlobalAveragePooling2D
from keras.layers.merge import add
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras import backend as K

# %%
def _bn_relu(input):
    """Helper to build a BN -> relu block
    """
    norm = BatchNormalization(axis=CHANNEL_AXIS)(input)
    return Activation("relu")(norm)


def _conv_bn_relu(**conv_params):
    """Helper to build a conv -> BN -> relu block
    """
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))

    def f(input):
        conv = Conv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer)(input)
        return _bn_relu(conv)

    return f


def _bn_relu_conv(**conv_params):
    """Helper to build a BN -> relu -> conv block.
    This is an improved scheme proposed in http://arxiv.org/pdf/1603.05027v2.pdf
    """
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))

    def f(input):
        activation = _bn_relu(input)
        return Conv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer)(activation)

    return f


def _shortcut(input, residual):
    """Adds a shortcut between input and residual block and merges them with "sum"
    """
    # Expand channels of shortcut to match residual.
    # Stride appropriately to match residual (width, height)
    # Should be int if network architecture is correctly configured.
    input_shape = K.int_shape(input)
    residual_shape = K.int_shape(residual)
    stride_width = int(round(input_shape[ROW_AXIS] / residual_shape[ROW_AXIS]))
    stride_height = int(round(input_shape[COL_AXIS] / residual_shape[COL_AXIS]))
    equal_channels = input_shape[CHANNEL_AXIS] == residual_shape[CHANNEL_AXIS]

    shortcut = input
    # 1 X 1 conv if shape is different. Else identity.
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Conv2D(filters=residual_shape[CHANNEL_AXIS],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid",
                          kernel_initializer="he_normal",
                          kernel_regularizer=l2(0.0001))(input)

    return add([shortcut, residual])


def _residual_block(block_function, filters, repetitions, is_first_layer=False):
    """Builds a residual block with repeating bottleneck blocks.
    """
    def f(input):
        for i in range(repetitions):
            init_strides = (1, 1)
            if i == 0 and not is_first_layer:
                init_strides = (2, 2)
            input = block_function(filters=filters, init_strides=init_strides,
                                   is_first_block_of_first_layer=(is_first_layer and i == 0))(input)
        return input

    return f


def basic_block(filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    """Basic 3 X 3 convolution blocks for use on resnets with layers <= 34.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    """
    def f(input):

        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv1 = Conv2D(filters=filters, kernel_size=(3, 3),
                           strides=init_strides,
                           padding="same",
                           kernel_initializer="he_normal",
                           kernel_regularizer=l2(1e-4))(input)
        else:
            conv1 = _bn_relu_conv(filters=filters, kernel_size=(3, 3),
                                  strides=init_strides)(input)

        residual = _bn_relu_conv(filters=filters, kernel_size=(3, 3))(conv1)
        return _shortcut(input, residual)

    return f


def bottleneck(filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    """Bottleneck architecture for > 34 layer resnet.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    Returns:
        A final conv layer of filters * 4
    """
    def f(input):

        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv_1_1 = Conv2D(filters=filters, kernel_size=(1, 1),
                              strides=init_strides,
                              padding="same",
                              kernel_initializer="he_normal",
                              kernel_regularizer=l2(1e-4))(input)
        else:
            conv_1_1 = _bn_relu_conv(filters=filters, kernel_size=(1, 1),
                                     strides=init_strides)(input)

        conv_3_3 = _bn_relu_conv(filters=filters, kernel_size=(3, 3))(conv_1_1)
        residual = _bn_relu_conv(filters=filters * 4, kernel_size=(1, 1))(conv_3_3)
        return _shortcut(input, residual)

    return f


def _handle_dim_ordering():
    global ROW_AXIS
    global COL_AXIS
    global CHANNEL_AXIS
    if K.image_dim_ordering() == 'tf':
        ROW_AXIS = 1
        COL_AXIS = 2
        CHANNEL_AXIS = 3
    else:
        CHANNEL_AXIS = 1
        ROW_AXIS = 2
        COL_AXIS = 3


def _get_block(identifier):
    if isinstance(identifier, six.string_types):
        res = globals().get(identifier)
        if not res:
            raise ValueError('Invalid {}'.format(identifier))
        return res
    return identifier

# %% [markdown]
# ###Resnet Builder

# %%
class ResnetBuilder(object):
    @staticmethod
    def build(input_shape, num_outputs, block_fn, repetitions):
        """Builds a custom ResNet like architecture.
        Args:
            input_shape: The input shape in the form (nb_channels, nb_rows, nb_cols)
            num_outputs: The number of outputs at final softmax layer
            block_fn: The block function to use. This is either `basic_block` or `bottleneck`.
                The original paper used basic_block for layers < 50
            repetitions: Number of repetitions of various block units.
                At each block unit, the number of filters are doubled and the input size is halved
        Returns:
            The keras `Model`.
        """
        _handle_dim_ordering()
        if len(input_shape) != 3:
            raise Exception("Input shape should be a tuple (nb_channels, nb_rows, nb_cols)")

        # Permute dimension order if necessary
        if K.image_dim_ordering() == 'tf':
            input_shape = (input_shape[1], input_shape[2], input_shape[0])

        # Load function from str if needed.
        block_fn = _get_block(block_fn)

        input = Input(shape=input_shape)
        conv1 = _conv_bn_relu(filters=64, kernel_size=(7, 7), strides=(2, 2))(input)
        pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(conv1)

        block = pool1
        filters = 64
        for i, r in enumerate(repetitions):
            block = _residual_block(block_fn, filters=filters, repetitions=r, is_first_layer=(i == 0))(block)
            filters *= 2

        # Last activation
        block = _bn_relu(block)

        # Classifier block
        block_shape = K.int_shape(block)
        pool2 = AveragePooling2D(pool_size=(block_shape[ROW_AXIS], block_shape[COL_AXIS]),
                                 strides=(1, 1))(block)
        gpa = GlobalAveragePooling2D()(pool2)       
        predictions = Dense(input_shape[1], activation='softmax')(gpa)

#         flatten1 = Flatten()(pool2)
#         dense = Dense(units=num_outputs, kernel_initializer="he_normal",
#                       activation="softmax")(flatten1)

        model = Model(inputs=input, outputs=predictions)
        return model

    @staticmethod
    def build_resnet_18(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, basic_block, [2, 2, 2, 2])

    @staticmethod
    def build_resnet_34(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, basic_block, [3, 4, 6, 3])

    @staticmethod
    def build_resnet_50(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 4, 6, 3])

    @staticmethod
    def build_resnet_101(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 4, 23, 3])

    @staticmethod
    def build_resnet_152(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 8, 36, 3])

# %%
# input image dimensions
img_rows, img_cols = 64, 64
# The e images are RGB.
img_channels = 3
nb_classes = 200

# %% [markdown]
# ##Cyclic Learning rate callback

# %%
from keras.callbacks import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os

import tensorflow as tf
from tensorflow import keras

tf.__version__
# Out:
# '1.13.1'

# %%
from keras.callbacks import *

from keras.optimizers import Adam


# Returns a short sequential model
def create_model():
  
  model = ResnetBuilder.build_resnet_34((img_channels, img_rows, img_cols), nb_classes)
  
  model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
#   model.compile(optimizer=tf.keras.optimizers.Adam(),
#                 loss=tf.keras.losses.sparse_categorical_crossentropy,
#                 metrics=['accuracy'])
  
  return model


# Create a basic model instance
model = create_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 32, 32, 64)   9472        input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 32, 32, 64)   256         conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 32, 32, 64)   0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_133[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 16, 16, 64)   36928       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 16, 16, 64)   256         conv2d_146[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 16, 16, 64)   0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 16, 16, 64)   36928       activation_134[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 16, 16, 64)   0           max_pooling2d_5[0][0]
#                                                                  conv2d_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 16, 16, 64)   256         add_65[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 16, 16, 64)   0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 16, 16, 64)   36928       activation_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 16, 16, 64)   256         conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 16, 16, 64)   0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 16, 16, 64)   36928       activation_136[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 16, 16, 64)   0           add_65[0][0]
#                                                                  conv2d_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 16, 16, 64)   256         add_66[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 16, 16, 64)   0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 16, 16, 64)   36928       activation_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 16, 16, 64)   256         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 16, 16, 64)   0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 16, 16, 64)   36928       activation_138[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 16, 16, 64)   0           add_66[0][0]
#                                                                  conv2d_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 16, 16, 64)   256         add_67[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 16, 16, 64)   0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 8, 8, 128)    73856       activation_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 8, 8, 128)    512         conv2d_152[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 8, 8, 128)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 8, 8, 128)    8320        add_67[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 8, 8, 128)    147584      activation_140[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 8, 8, 128)    0           conv2d_154[0][0]
#                                                                  conv2d_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 8, 8, 128)    512         add_68[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 8, 8, 128)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 8, 8, 128)    147584      activation_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 8, 8, 128)    512         conv2d_155[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 8, 8, 128)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 8, 8, 128)    147584      activation_142[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 8, 8, 128)    0           add_68[0][0]
#                                                                  conv2d_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 8, 8, 128)    512         add_69[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 8, 8, 128)    0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 8, 8, 128)    147584      activation_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 8, 8, 128)    512         conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 8, 8, 128)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 8, 8, 128)    147584      activation_144[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 8, 8, 128)    0           add_69[0][0]
#                                                                  conv2d_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 8, 8, 128)    512         add_70[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 8, 8, 128)    0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 8, 8, 128)    147584      activation_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 8, 8, 128)    512         conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 8, 8, 128)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 8, 8, 128)    147584      activation_146[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 8, 8, 128)    0           add_70[0][0]
#                                                                  conv2d_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 8, 8, 128)    512         add_71[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 8, 8, 128)    0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 4, 4, 256)    295168      activation_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 4, 4, 256)    1024        conv2d_161[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 4, 4, 256)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 4, 4, 256)    33024       add_71[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 4, 4, 256)    590080      activation_148[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 4, 4, 256)    0           conv2d_163[0][0]
#                                                                  conv2d_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 4, 4, 256)    1024        add_72[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 4, 4, 256)    0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 4, 4, 256)    590080      activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 4, 4, 256)    1024        conv2d_164[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 4, 4, 256)    0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 4, 4, 256)    590080      activation_150[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 4, 4, 256)    0           add_72[0][0]
#                                                                  conv2d_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 4, 4, 256)    1024        add_73[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 4, 4, 256)    0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 4, 4, 256)    590080      activation_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 4, 4, 256)    1024        conv2d_166[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 4, 4, 256)    0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 4, 4, 256)    590080      activation_152[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 4, 4, 256)    0           add_73[0][0]
#                                                                  conv2d_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 4, 4, 256)    1024        add_74[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 4, 4, 256)    0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 4, 4, 256)    590080      activation_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 4, 4, 256)    1024        conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 4, 4, 256)    0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 4, 4, 256)    590080      activation_154[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 4, 4, 256)    0           add_74[0][0]
#                                                                  conv2d_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 4, 4, 256)    1024        add_75[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 4, 4, 256)    0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 4, 4, 256)    590080      activation_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 4, 4, 256)    1024        conv2d_170[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 4, 4, 256)    0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 4, 4, 256)    590080      activation_156[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 4, 4, 256)    0           add_75[0][0]
#                                                                  conv2d_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 4, 4, 256)    1024        add_76[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 4, 4, 256)    0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 4, 4, 256)    590080      activation_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 4, 4, 256)    1024        conv2d_172[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 4, 4, 256)    0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 4, 4, 256)    590080      activation_158[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 4, 4, 256)    0           add_76[0][0]
#                                                                  conv2d_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 4, 4, 256)    1024        add_77[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 4, 4, 256)    0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 2, 2, 512)    1180160     activation_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 2, 2, 512)    2048        conv2d_174[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 2, 2, 512)    0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 2, 2, 512)    131584      add_77[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 2, 2, 512)    2359808     activation_160[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 2, 2, 512)    0           conv2d_176[0][0]
#                                                                  conv2d_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 2, 2, 512)    2048        add_78[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 2, 2, 512)    0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 2, 2, 512)    2359808     activation_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 2, 2, 512)    2048        conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 2, 2, 512)    0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 2, 2, 512)    2359808     activation_162[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 2, 2, 512)    0           add_78[0][0]
#                                                                  conv2d_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 2, 2, 512)    2048        add_79[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 2, 2, 512)    0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 2, 2, 512)    2359808     activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 2, 2, 512)    2048        conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 2, 2, 512)    0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 2, 2, 512)    2359808     activation_164[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 2, 2, 512)    0           add_79[0][0]
#                                                                  conv2d_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 2, 2, 512)    2048        add_80[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 2, 2, 512)    0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 1, 1, 512)    0           activation_165[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           32832       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 21,339,456
# Trainable params: 21,324,224
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
import timeit

checkpoint_path = "training_3/cp-{epoch:04d}.hdf5"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, verbose=1, save_weights_only=True,
    # Save weights, every 5-epochs.
    period=5)

model = create_model()
model.save_weights(checkpoint_path.format(epoch=0))

startTime = timeit.default_timer()
clr_triangular = CyclicLR(mode='triangular')


model.fit_generator(train_generator, epochs=300, steps_per_epoch=100000//1024, validation_steps=10000//1024, validation_data=validation_generator, callbacks=[cp_callback, clr_triangular])

elapsedTime = timeit.default_timer() - startTime
print("Time taken for the Network to train : ",elapsedTime)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/120
# 195/195 [==============================] - 270s 1s/step - loss: 5.5923 - acc: 0.0786 - val_loss: 5.6239 - val_acc: 0.0714
# Epoch 2/120
# 195/195 [==============================] - 252s 1s/step - loss: 4.5788 - acc: 0.1354 - val_loss: 4.6443 - val_acc: 0.1133
# Epoch 3/120
# 195/195 [==============================] - 251s 1s/step - loss: 4.2743 - acc: 0.1655 - val_loss: 4.5401 - val_acc: 0.1337
# Epoch 4/120
# 195/195 [==============================] - 250s 1s/step - loss: 4.1121 - acc: 0.1875 - val_loss: 4.4627 - val_acc: 0.1344
# Epoch 5/120
# 195/195 [==============================] - 251s 1s/step - loss: 4.0031 - acc: 0.2047 - val_loss: 4.6784 - val_acc: 0.1080
#
# Epoch 00005: saving model to training_2/cp-0005.hdf5
# Epoch 6/120
# 195/195 [==============================] - 250s 1s/step - loss: 3.8983 - acc: 0.2211 - val_loss: 4.5201 - val_acc: 0.1421
# Epoch 7/120
# 195/195 [==============================] - 250s 1s/step - loss: 3.8508 - acc: 0.2327 - val_loss: 4.4822 - val_acc: 0.1614
# Epoch 8/120
# 195/195 [==============================] - 250s 1s/step - loss: 3.8130 - acc: 0.2402 - val_loss: 4.4079 - val_acc: 0.1480
# Epoch 9/120
# 195/195 [==============================] - 250s 1s/step - loss: 3.7941 - acc: 0.2472 - val_loss: 4.2015 - val_acc: 0.1906
# Epoch 10/120
# 195/195 [==============================] - 250s 1s/step - loss: 3.7975 - acc: 0.2512 - val_loss: 4.2984 - val_acc: 0.1745
#
# Epoch 00010: saving model to training_2/cp-0010.hdf5
# Epoch 11/120
# 195/195 [==============================] - 250s 1s/step - loss: 3.7661 - acc: 0.2597 - val_loss: 4.1504 - val_acc: 0.1988
# Epoch 12/120
# 195/195 [==============================] - 251s 1s/step - loss: 3.6855 - acc: 0.2734 - val_loss: 4.2661 - val_acc: 0.1868
# Epoch 13/120
# 195/195 [==============================] - 251s 1s/step - loss: 3.6025 - acc: 0.2847 - val_loss: 4.0866 - val_acc: 0.2120
# Epoch 14/120
# 195/195 [==============================] - 252s 1s/step - loss: 3.4985 - acc: 0.3010 - val_loss: 3.9642 - val_acc: 0.2253
# Epoch 15/120
# 195/195 [==============================] - 251s 1s/step - loss: 3.4190 - acc: 0.3129 - val_loss: 3.6623 - val_acc: 0.2681
#
# Epoch 00015: saving model to training_2/cp-0015.hdf5
# Epoch 16/120
# 195/195 [==============================] - 250s 1s/step - loss: 3.3180 - acc: 0.3297 - val_loss: 3.4848 - val_acc: 0.2954
# Epoch 17/120
# 195/195 [==============================] - 242s 1s/step - loss: 3.2098 - acc: 0.3464 - val_loss: 3.4766 - val_acc: 0.2976
# Epoch 18/120
# 195/195 [==============================] - 243s 1s/step - loss: 3.1143 - acc: 0.3605 - val_loss: 3.4335 - val_acc: 0.3091
# Epoch 19/120
# 195/195 [==============================] - 251s 1s/step - loss: 2.9981 - acc: 0.3807 - val_loss: 3.1442 - val_acc: 0.3512
# Epoch 20/120
# 195/195 [==============================] - 254s 1s/step - loss: 2.8707 - acc: 0.4011 - val_loss: 3.0582 - val_acc: 0.3675
#
# Epoch 00020: saving model to training_2/cp-0020.hdf5
# Epoch 21/120
# 195/195 [==============================] - 256s 1s/step - loss: 2.7703 - acc: 0.4181 - val_loss: 3.0909 - val_acc: 0.3617
# Epoch 22/120
# 195/195 [==============================] - 254s 1s/step - loss: 2.7760 - acc: 0.4172 - val_loss: 3.1139 - val_acc: 0.3587
# Epoch 23/120
# 195/195 [==============================] - 255s 1s/step - loss: 2.8547 - acc: 0.3985 - val_loss: 3.2723 - val_acc: 0.3247
# Epoch 24/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.9353 - acc: 0.3890 - val_loss: 3.7808 - val_acc: 0.2654
# Epoch 25/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.9979 - acc: 0.3801 - val_loss: 3.6177 - val_acc: 0.2847
#
# Epoch 00025: saving model to training_2/cp-0025.hdf5
# Epoch 26/120
# 195/195 [==============================] - 255s 1s/step - loss: 3.0594 - acc: 0.3735 - val_loss: 3.8552 - val_acc: 0.2499
# Epoch 27/120
# 195/195 [==============================] - 255s 1s/step - loss: 3.0998 - acc: 0.3687 - val_loss: 4.0784 - val_acc: 0.2507
# Epoch 28/120
# 195/195 [==============================] - 254s 1s/step - loss: 3.1683 - acc: 0.3623 - val_loss: 3.8376 - val_acc: 0.2773
# Epoch 29/120
# 195/195 [==============================] - 251s 1s/step - loss: 3.1967 - acc: 0.3610 - val_loss: 3.9112 - val_acc: 0.2602
# Epoch 30/120
# 195/195 [==============================] - 251s 1s/step - loss: 3.2482 - acc: 0.3548 - val_loss: 3.9295 - val_acc: 0.2664
#
# Epoch 00030: saving model to training_2/cp-0030.hdf5
# Epoch 31/120
# 195/195 [==============================] - 252s 1s/step - loss: 3.2901 - acc: 0.3507 - val_loss: 3.7333 - val_acc: 0.2868
# Epoch 32/120
# 195/195 [==============================] - 253s 1s/step - loss: 3.2740 - acc: 0.3528 - val_loss: 4.1501 - val_acc: 0.2276
# Epoch 33/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.2155 - acc: 0.3646 - val_loss: 3.5369 - val_acc: 0.3035
# Epoch 34/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.1393 - acc: 0.3750 - val_loss: 3.5266 - val_acc: 0.3147
# Epoch 35/120
# 195/195 [==============================] - 255s 1s/step - loss: 3.0804 - acc: 0.3850 - val_loss: 3.6589 - val_acc: 0.2923
#
# Epoch 00035: saving model to training_2/cp-0035.hdf5
# Epoch 36/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.0072 - acc: 0.3987 - val_loss: 3.4558 - val_acc: 0.3295
# Epoch 37/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.9301 - acc: 0.4083 - val_loss: 3.4323 - val_acc: 0.3255
# Epoch 38/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.8364 - acc: 0.4226 - val_loss: 3.1734 - val_acc: 0.3633
# Epoch 39/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.7489 - acc: 0.4363 - val_loss: 3.0913 - val_acc: 0.3879
# Epoch 40/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.6441 - acc: 0.4546 - val_loss: 2.8796 - val_acc: 0.4091
#
# Epoch 00040: saving model to training_2/cp-0040.hdf5
# Epoch 41/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.5482 - acc: 0.4696 - val_loss: 2.8092 - val_acc: 0.4314
# Epoch 42/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.4795 - acc: 0.4806 - val_loss: 3.3256 - val_acc: 0.3426
# Epoch 43/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.5542 - acc: 0.4630 - val_loss: 3.4383 - val_acc: 0.3343
# Epoch 44/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.6371 - acc: 0.4503 - val_loss: 3.4351 - val_acc: 0.3119
# Epoch 45/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.7239 - acc: 0.4350 - val_loss: 3.6684 - val_acc: 0.3058
#
# Epoch 00045: saving model to training_2/cp-0045.hdf5
# Epoch 46/120
# 195/195 [==============================] - 255s 1s/step - loss: 2.7918 - acc: 0.4254 - val_loss: 3.3340 - val_acc: 0.3412
# Epoch 47/120
# 195/195 [==============================] - 256s 1s/step - loss: 2.8622 - acc: 0.4185 - val_loss: 3.4463 - val_acc: 0.3272
# Epoch 48/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.9282 - acc: 0.4069 - val_loss: 3.5642 - val_acc: 0.3132
# Epoch 49/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.9889 - acc: 0.3987 - val_loss: 3.7044 - val_acc: 0.2934
# Epoch 50/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.0453 - acc: 0.3927 - val_loss: 3.9152 - val_acc: 0.2644
#
# Epoch 00050: saving model to training_2/cp-0050.hdf5
# Epoch 51/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.1047 - acc: 0.3852 - val_loss: 3.8904 - val_acc: 0.2721
# Epoch 52/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.1354 - acc: 0.3851 - val_loss: 4.0460 - val_acc: 0.2422
# Epoch 53/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.0941 - acc: 0.3917 - val_loss: 3.8288 - val_acc: 0.2799
# Epoch 54/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.0326 - acc: 0.4032 - val_loss: 3.6114 - val_acc: 0.3081
# Epoch 55/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.9643 - acc: 0.4111 - val_loss: 3.5447 - val_acc: 0.3208
#
# Epoch 00055: saving model to training_2/cp-0055.hdf5
# Epoch 56/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.9044 - acc: 0.4200 - val_loss: 3.4985 - val_acc: 0.3275
# Epoch 57/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.8352 - acc: 0.4309 - val_loss: 3.4343 - val_acc: 0.3351
# Epoch 58/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.7584 - acc: 0.4411 - val_loss: 3.1871 - val_acc: 0.3729
# Epoch 59/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.6572 - acc: 0.4577 - val_loss: 3.0336 - val_acc: 0.4011
# Epoch 60/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.5813 - acc: 0.4707 - val_loss: 3.0538 - val_acc: 0.3926
#
# Epoch 00060: saving model to training_2/cp-0060.hdf5
# Epoch 61/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.4691 - acc: 0.4925 - val_loss: 2.9030 - val_acc: 0.4227
# Epoch 62/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.3722 - acc: 0.5080 - val_loss: 2.8017 - val_acc: 0.4372
# Epoch 63/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.3813 - acc: 0.5033 - val_loss: 3.1657 - val_acc: 0.3698
# Epoch 64/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.4736 - acc: 0.4841 - val_loss: 3.3607 - val_acc: 0.3616
# Epoch 65/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.5533 - acc: 0.4673 - val_loss: 3.8128 - val_acc: 0.2810
#
# Epoch 00065: saving model to training_2/cp-0065.hdf5
# Epoch 66/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.6513 - acc: 0.4529 - val_loss: 3.4724 - val_acc: 0.3340
# Epoch 67/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.7269 - acc: 0.4417 - val_loss: 3.8179 - val_acc: 0.2875
# Epoch 68/120
# 195/195 [==============================] - 256s 1s/step - loss: 2.7916 - acc: 0.4322 - val_loss: 3.6706 - val_acc: 0.3175
# Epoch 69/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.8774 - acc: 0.4203 - val_loss: 3.8081 - val_acc: 0.2878
# Epoch 70/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.9187 - acc: 0.4164 - val_loss: 3.9799 - val_acc: 0.2851
#
# Epoch 00070: saving model to training_2/cp-0070.hdf5
# Epoch 71/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.9911 - acc: 0.4090 - val_loss: 3.9734 - val_acc: 0.2616
# Epoch 72/120
# 195/195 [==============================] - 258s 1s/step - loss: 3.0425 - acc: 0.4025 - val_loss: 4.0464 - val_acc: 0.2796
# Epoch 73/120
# 195/195 [==============================] - 257s 1s/step - loss: 3.0324 - acc: 0.4053 - val_loss: 4.0044 - val_acc: 0.2631
# Epoch 74/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.9752 - acc: 0.4158 - val_loss: 3.7939 - val_acc: 0.2821
# Epoch 75/120
# 195/195 [==============================] - 260s 1s/step - loss: 2.9217 - acc: 0.4252 - val_loss: 3.8930 - val_acc: 0.2740
#
# Epoch 00075: saving model to training_2/cp-0075.hdf5
# Epoch 76/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.8406 - acc: 0.4361 - val_loss: 3.5998 - val_acc: 0.3153
# Epoch 77/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.7895 - acc: 0.4425 - val_loss: 3.8012 - val_acc: 0.2970
# Epoch 78/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.7188 - acc: 0.4555 - val_loss: 3.5012 - val_acc: 0.3320
# Epoch 79/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.6293 - acc: 0.4672 - val_loss: 3.3116 - val_acc: 0.3653
# Epoch 80/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.5466 - acc: 0.4825 - val_loss: 3.1673 - val_acc: 0.3813
#
# Epoch 00080: saving model to training_2/cp-0080.hdf5
# Epoch 81/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.4523 - acc: 0.4988 - val_loss: 2.9805 - val_acc: 0.4124
# Epoch 82/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.3502 - acc: 0.5157 - val_loss: 2.7840 - val_acc: 0.4435
# Epoch 83/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.3017 - acc: 0.5240 - val_loss: 2.8252 - val_acc: 0.4427
# Epoch 84/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.3569 - acc: 0.5067 - val_loss: 3.1420 - val_acc: 0.3879
# Epoch 85/120
# 195/195 [==============================] - 258s 1s/step - loss: 2.4374 - acc: 0.4921 - val_loss: 3.2892 - val_acc: 0.3596
#
# Epoch 00085: saving model to training_2/cp-0085.hdf5
# Epoch 86/120
# 195/195 [==============================] - 257s 1s/step - loss: 2.5347 - acc: 0.4750 - val_loss: 3.4641 - val_acc: 0.3384
# Epoch 87/120
# 195/195 [==============================] - 259s 1s/step - loss: 2.6181 - acc: 0.4597 - val_loss: 3.5511 - val_acc: 0.3273
# Epoch 88/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.6958 - acc: 0.4498 - val_loss: 3.7107 - val_acc: 0.3050
# Epoch 89/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.7624 - acc: 0.4410 - val_loss: 3.7540 - val_acc: 0.3103
# Epoch 90/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.8288 - acc: 0.4337 - val_loss: 3.5559 - val_acc: 0.3258
#
# Epoch 00090: saving model to training_2/cp-0090.hdf5
# Epoch 91/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.8991 - acc: 0.4231 - val_loss: 3.8078 - val_acc: 0.3006
# Epoch 92/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.9490 - acc: 0.4180 - val_loss: 3.6201 - val_acc: 0.3327
# Epoch 93/120
# 195/195 [==============================] - 261s 1s/step - loss: 2.9987 - acc: 0.4124 - val_loss: 4.0019 - val_acc: 0.2771
# Epoch 94/120
# 195/195 [==============================] - 261s 1s/step - loss: 2.9454 - acc: 0.4226 - val_loss: 3.7149 - val_acc: 0.2972
# Epoch 95/120
# 195/195 [==============================] - 261s 1s/step - loss: 2.8749 - acc: 0.4334 - val_loss: 3.6379 - val_acc: 0.3231
#
# Epoch 00095: saving model to training_2/cp-0095.hdf5
# Epoch 96/120
# 195/195 [==============================] - 261s 1s/step - loss: 2.8319 - acc: 0.4404 - val_loss: 3.8757 - val_acc: 0.2857
# Epoch 97/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.7599 - acc: 0.4506 - val_loss: 3.6495 - val_acc: 0.3169
# Epoch 98/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.6991 - acc: 0.4596 - val_loss: 3.3927 - val_acc: 0.3555
# Epoch 99/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.6196 - acc: 0.4724 - val_loss: 3.3241 - val_acc: 0.3648
# Epoch 100/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.5380 - acc: 0.4861 - val_loss: 3.0391 - val_acc: 0.4055
#
# Epoch 00100: saving model to training_2/cp-0100.hdf5
# Epoch 101/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.4464 - acc: 0.5029 - val_loss: 3.0626 - val_acc: 0.4034
# Epoch 102/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.3536 - acc: 0.5187 - val_loss: 2.9228 - val_acc: 0.4204
# Epoch 103/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.2718 - acc: 0.5332 - val_loss: 2.8310 - val_acc: 0.4401
# Epoch 104/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.2588 - acc: 0.5311 - val_loss: 3.0245 - val_acc: 0.4096
# Epoch 105/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.3452 - acc: 0.5117 - val_loss: 3.1449 - val_acc: 0.3832
#
# Epoch 00105: saving model to training_2/cp-0105.hdf5
# Epoch 106/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.4358 - acc: 0.4921 - val_loss: 3.6824 - val_acc: 0.3097
# Epoch 107/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.5274 - acc: 0.4775 - val_loss: 3.6355 - val_acc: 0.3265
# Epoch 108/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.6117 - acc: 0.4651 - val_loss: 3.6470 - val_acc: 0.3405
# Epoch 109/120
# 195/195 [==============================] - 264s 1s/step - loss: 2.6845 - acc: 0.4540 - val_loss: 4.0928 - val_acc: 0.2899
# Epoch 110/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.7521 - acc: 0.4446 - val_loss: 3.6392 - val_acc: 0.3118
#
# Epoch 00110: saving model to training_2/cp-0110.hdf5
# Epoch 111/120
# 195/195 [==============================] - 264s 1s/step - loss: 2.8285 - acc: 0.4347 - val_loss: 3.9525 - val_acc: 0.2875
# Epoch 112/120
# 195/195 [==============================] - 264s 1s/step - loss: 2.8815 - acc: 0.4280 - val_loss: 3.7412 - val_acc: 0.3066
# Epoch 113/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.9499 - acc: 0.4208 - val_loss: 4.2809 - val_acc: 0.2431
# Epoch 114/120
# 195/195 [==============================] - 264s 1s/step - loss: 2.9367 - acc: 0.4227 - val_loss: 3.7066 - val_acc: 0.3244
# Epoch 115/120
# 195/195 [==============================] - 264s 1s/step - loss: 2.8689 - acc: 0.4370 - val_loss: 3.6643 - val_acc: 0.3142
#
# Epoch 00115: saving model to training_2/cp-0115.hdf5
# Epoch 116/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.8189 - acc: 0.4451 - val_loss: 3.5602 - val_acc: 0.3247
# Epoch 117/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.7620 - acc: 0.4531 - val_loss: 3.3937 - val_acc: 0.3559
# Epoch 118/120
# 195/195 [==============================] - 263s 1s/step - loss: 2.6846 - acc: 0.4648 - val_loss: 3.7176 - val_acc: 0.3120
# Epoch 119/120
# 195/195 [==============================] - 262s 1s/step - loss: 2.6197 - acc: 0.4752 - val_loss: 3.3234 - val_acc: 0.3644
# Epoch 120/120
# 195/195 [==============================] - 261s 1s/step - loss: 2.5381 - acc: 0.4879 - val_loss: 3.2133 - val_acc: 0.3720
#
# Epoch 00120: saving model to training_2/cp-0120.hdf5
# Time taken for the Network to train :  30923.749253329

# %%
# !ls {checkpoint_dir}
# Out:
# cp-0000.hdf5  cp-0025.hdf5  cp-0050.hdf5  cp-0075.hdf5	cp-0100.hdf5
# cp-0005.hdf5  cp-0030.hdf5  cp-0055.hdf5  cp-0080.hdf5	cp-0105.hdf5
# cp-0010.hdf5  cp-0035.hdf5  cp-0060.hdf5  cp-0085.hdf5	cp-0110.hdf5
# cp-0015.hdf5  cp-0040.hdf5  cp-0065.hdf5  cp-0090.hdf5	cp-0115.hdf5
# cp-0020.hdf5  cp-0045.hdf5  cp-0070.hdf5  cp-0095.hdf5	cp-0120.hdf5

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest

# %%
model = create_model()
scores = model.evaluate_generator(validation_generator, steps=10000//512)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# Baseline Error: 99.42%

# %%
model.load_weights("training_2/cp-0120.hdf5")
loss, acc = model.evaluate_generator(validation_generator, steps=10000//512)
# print(scores)
print("Baseline Error: %.2f%%" % (100-acc*100))
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# Baseline Error: 62.69%
# Restored model, accuracy: 37.31%
